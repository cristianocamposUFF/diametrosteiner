# %%
C5= graphs.PetersenGraph()
C5.show()
# Out:
# Graphics object consisting of 26 graphics primitives

# %%
from itertools import combinations

S = 2

x=C5.vertices()

comb = combinations(x , 2)
l=list(comb)
dic={}

for i in l:
        print i
        st=C5.steiner_tree(i)
        print st.size()
        dic[i]= st.size()
# Out:
# (0, 1)
# 1
# (0, 2)
# 2
# (0, 3)
# 2
# (0, 4)
# 1
# (0, 5)
# 1
# (0, 6)
# 2
# (0, 7)
# 2
# (0, 8)
# 2
# (0, 9)
# 2
# (1, 2)
# 1
# (1, 3)
# 2
# (1, 4)
# 2
# (1, 5)
# 2
# (1, 6)
# 1
# (1, 7)
# 2
# (1, 8)
# 2
# (1, 9)
# 2
# (2, 3)
# 1
# (2, 4)
# 2
# (2, 5)
# 2
# (2, 6)
# 2
# (2, 7)
# 1
# (2, 8)
# 2
# (2, 9)
# 2
# (3, 4)
# 1
# (3, 5)
# 2
# (3, 6)
# 2
# (3, 7)
# 2
# (3, 8)
# 1
# (3, 9)
# 2
# (4, 5)
# 2
# (4, 6)
# 2
# (4, 7)
# 2
# (4, 8)
# 2
# (4, 9)
# 1
# (5, 6)
# 2
# (5, 7)
# 1
# (5, 8)
# 1
# (5, 9)
# 2
# (6, 7)
# 2
# (6, 8)
# 1
# (6, 9)
# 1
# (7, 8)
# 2
# (7, 9)
# 1
# (8, 9)
# 2

# %%
print dic

l1=dic.values()
# Out:
# {(5, 9): 2, (4, 7): 2, (1, 3): 2, (4, 8): 2, (5, 6): 2, (2, 8): 2, (6, 9): 1, (0, 7): 2, (8, 9): 2, (1, 6): 1, (3, 7): 2, (2, 5): 2, (0, 3): 2, (5, 8): 1, (1, 2): 1, (4, 9): 1, (2, 9): 2, (1, 5): 2, (3, 6): 2, (0, 4): 1, (7, 9): 1, (2, 7): 1, (2, 6): 2, (4, 5): 2, (1, 4): 2, (3, 9): 2, (2, 3): 1, (1, 9): 2, (6, 8): 1, (6, 7): 2, (0, 8): 2, (3, 5): 2, (0, 1): 1, (4, 6): 2, (7, 8): 2, (5, 7): 1, (0, 2): 2, (3, 8): 1, (0, 6): 2, (1, 8): 2, (1, 7): 2, (0, 9): 2, (0, 5): 1, (3, 4): 1, (2, 4): 2}

# %%
print l1

x=max(l1)
print("Sdiamk = %d" %x)
# Out:
# [2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2, 1, 1, 2]
# Sdiamk = 2

# %%
print("Familías de Árvore S-Steiner com ordem %d" %x)
for i in dic:
    if dic[i] == x:
        print i
        st1=C5.steiner_tree(i)
        st1.show()
# Out:
# Familías de Árvore S-Steiner com ordem 2
# (5, 9)
# Graphics object consisting of 6 graphics primitives
# (4, 7)
# Graphics object consisting of 6 graphics primitives
# (1, 3)
# Graphics object consisting of 6 graphics primitives
# (4, 8)
# Graphics object consisting of 6 graphics primitives
# (5, 6)
# Graphics object consisting of 6 graphics primitives
# (2, 8)
# Graphics object consisting of 6 graphics primitives
# (0, 7)
# Graphics object consisting of 6 graphics primitives
# (8, 9)
# Graphics object consisting of 6 graphics primitives
# (3, 7)
# Graphics object consisting of 6 graphics primitives
# (2, 5)
# Graphics object consisting of 6 graphics primitives
# (0, 3)
# Graphics object consisting of 6 graphics primitives
# (2, 9)
# Graphics object consisting of 6 graphics primitives
# (1, 5)
# Graphics object consisting of 6 graphics primitives
# (3, 6)
# Graphics object consisting of 6 graphics primitives
# (2, 6)
# Graphics object consisting of 6 graphics primitives
# (4, 5)
# ...

# %%
G=graphs.CycleGraph(8)
G.show()
# Out:
# Graphics object consisting of 17 graphics primitives

# %%
from itertools import combinations

S = 3

x=G.vertices()

comb = combinations(x , S)
l=list(comb)
dic={}

for i in l:
        print i
        st=G.steiner_tree(i)
        print st.size()
        dic[i]= st.size()
# Out:
# (0, 1, 2)
# 2
# (0, 1, 3)
# 3
# (0, 1, 4)
# 4
# (0, 1, 5)
# 4
# (0, 1, 6)
# 3
# (0, 1, 7)
# 2
# (0, 2, 3)
# 3
# (0, 2, 4)
# 4
# (0, 2, 5)
# 5
# (0, 2, 6)
# 4
# (0, 2, 7)
# 3
# (0, 3, 4)
# 4
# (0, 3, 5)
# 5
# (0, 3, 6)
# 5
# (0, 3, 7)
# 4
# (0, 4, 5)
# 4
# (0, 4, 6)
# 4
# (0, 4, 7)
# 4
# (0, 5, 6)
# 3
# (0, 5, 7)
# 3
# (0, 6, 7)
# 2
# (1, 2, 3)
# 2
# (1, 2, 4)
# 3
# (1, 2, 5)
# 4
# (1, 2, 6)
# 4
# (1, 2, 7)
# 3
# (1, 3, 4)
# 3
# (1, 3, 5)
# 4
# (1, 3, 6)
# 5
# (1, 3, 7)
# 4
# (1, 4, 5)
# 4
# (1, 4, 6)
# 5
# (1, 4, 7)
# 5
# (1, 5, 6)
# 4
# (1, 5, 7)
# 4
# (1, 6, 7)
# 3
# (2, 3, 4)
# 2
# (2, 3, 5)
# 3
# (2, 3, 6)
# 4
# (2, 3, 7)
# 4
# (2, 4, 5)
# 3
# (2, 4, 6)
# 4
# (2, 4, 7)
# 5
# (2, 5, 6)
# 4
# (2, 5, 7)
# 5
# (2, 6, 7)
# 4
# (3, 4, 5)
# 2
# (3, 4, 6)
# 3
# (3, 4, 7)
# 4
# (3, 5, 6)
# 3
# (3, 5, 7)
# 4
# (3, 6, 7)
# 4
# (4, 5, 6)
# 2
# (4, 5, 7)
# 3
# (4, 6, 7)
# 3
# (5, 6, 7)
# 2

# %%
l1=dic.values()
x=max(l1)
print("Sdiamk = %d" %x)
# Out:
# Sdiamk = 5

# %%
print("Familías de Árvore S-Steiner com ordem %d" %x)
for i in dic:
    if dic[i] == x:
        print i
        st1=G.steiner_tree(i)
        st1.show()
# Out:
# Familías de Árvore S-Steiner com ordem 5
# (1, 4, 7)
# Graphics object consisting of 12 graphics primitives
# (2, 4, 7)
# Graphics object consisting of 12 graphics primitives
# (0, 2, 5)
# Graphics object consisting of 12 graphics primitives
# (2, 5, 7)
# Graphics object consisting of 12 graphics primitives
# (0, 3, 6)
# Graphics object consisting of 12 graphics primitives
# (1, 3, 6)
# Graphics object consisting of 12 graphics primitives
# (0, 3, 5)
# Graphics object consisting of 12 graphics primitives
# (1, 4, 6)
# Graphics object consisting of 12 graphics primitives
